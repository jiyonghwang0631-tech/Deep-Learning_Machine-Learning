# %%
import sys
print(sys.version)
# Out:
# 3.13.13 (main, May  4 2026, 21:18:21) [MSC v.1944 64 bit (AMD64)]

# %%
import keras

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
mlp = tf.keras.models.Sequential()

# %%
mnist = tf.keras.datasets.mnist.load_data()
print(mnist)

# %%
print(mnist[0][0])

# %%
data = mnist[0][0]
print(data)

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
#  (60000,)
#  (10000, 28, 28)
#  (10000,)

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Input(shape=(28*28,)))
model.add(tf.keras.layers.Dense(units=512, activation='relu', name='Hidden1'))
model.add(tf.keras.layers.Dense(units=256, activation='relu', name='Hidden2'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax', name='OutjuptLayer'))
model.summary()
# Out:
# Model: "sequential"
#  ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
#  ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
#  ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
#  │ Hidden1 (Dense)                 │ (None, 512)            │       401,920 │
#  │ Hidden2 (Dense)                 │ (None, 256)            │       131,328 │
#  │ OutjuptLayer (Dense)            │ (None, 10)             │         2,570 │
#  └─────────────────────────────────┴────────────────────────┴───────────────┘
#   Total params: 535,818 (2.04 MB)
#   Trainable params: 535,818 (2.04 MB)
#   Non-trainable params: 0 (0.00 B)

# %%
x_images = x_train.reshape((60000, 28*28))
ex1 = x_images[0] / 255
type(ex1.dtype)
# Out:
# numpy.dtypes.Float64DType

# %%
x_images_norm = (x_images / 255).astype('float32')

# %%
x_images_test = x_test.reshape(10000, 28*28)

# %%
x_images_test_norm = (x_images_test / 255).astype('float32')

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#model.fit(x_images_norm, y_train, epochs=20)

# %%
model.save("MNIST_20260626_15-35.keras")

# %%
model.evaluate(x_images_test_norm, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9802 - loss: 0.1753
#  [0.1753058284521103, 0.9801999926567078]

# %%
import cv2

# %%
img = cv2.imread("digital.png", cv2.IMREAD_GRAYSCALE)
cv2.imshow("IMG", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
resize_img = cv2.resize(img, (28, 28))

# %%
cv2.imshow("IMG", resize_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
resize_img = resize_img.astype('float32')

# %%
inverse_img = 255 - resize_img
cv2.imshow("IMG", inverse_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
inverse_img_norm = inverse_img / 255.0

# %%
print(inverse_img_norm.shape)
# Out:
# (28, 28)

# %%
result = model.predict(inverse_img_norm.reshape(1, 784))
print(result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#  [[2.7184061e-10 1.8942333e-07 3.1468554e-05 4.9216822e-05 1.2557392e-09
#    6.0217288e-10 1.4920045e-13 9.9991846e-01 7.1149803e-07 1.7119420e-08]]

# %%
print(result.argmax())
# Out:
# 7

# %%
# camera project_04 input
import cv2
import numpy as np

camera_img = cv2.imread('camera_IMAGE_FOR_TEST.png', cv2.IMREAD_GRAYSCALE)
if camera_img is None:
    raise FileNotFoundError('camera_IMAGE_FOR_TEST.png')

camera_resize = cv2.resize(camera_img, (28, 28), interpolation=cv2.INTER_AREA)
camera_norm = camera_resize.astype('float32') / 255.0
camera_result = model.predict(camera_norm.reshape(1, 784))
print(camera_result)
print('camera prediction:', int(camera_result.argmax()))
